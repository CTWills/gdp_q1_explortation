# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
gpd_data = pd.read_excel("../data/gdp_q1_data.xlsx", sheet_name="Table 1", index_col=1, skiprows=3)

# %%
gpd_data.sample(5)
# Out:
#                                                    Line  2021 2022 2023 r  \
# Exports                                              16   6.3    7    2.6
# Government consumption expenditures and gross i...   22  -0.3 -0.9    4.1
# Goods                                                20  14.6  6.8   -1.6
# Services                                             18   3.8  9.6    2.5
# Goods                                                17   7.6  5.8    2.6
#
#                                                       Q2     Q3    Q4   Q1  \
# Exports                                            -61.5     62  25.8  0.9
# Government consumption expenditures and gross i...   8.6   -6.1  -1.9  5.7
# Goods                                              -49.2  104.5  30.8  8.7
# Services                                           -49.4    2.7    22  2.7
# Goods                                              -66.9  106.6  27.5 -0.2
#
# ...
